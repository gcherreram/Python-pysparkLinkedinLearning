# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Gabo0/Desktop/Jupyter Python/Ejercicios Linkedin/base_datos_2008.csv", nrows = 100000)

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df.tail()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
# reordenar nuestra base de datos

# %%
df = df.sample(frac=1)

# %%
# Aqui podemos ver las columnas que hay en nuestra base

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime
# Out:
# 66896    1147.0
# 68652    1224.0
# 79787    1808.0
# 72143    2107.0
# 57048    1502.0
#           ...
# 17448    1223.0
# 95269     953.0
# 6832     1206.0
# 86657    1849.0
# 55564    1501.0
# Name: DepTime, Length: 100000, dtype: float64

# %% [markdown]
# Explorar los distintos tipos devariables

# %%
df.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df.values
# Out:
# array([[2008, 1, 23, ..., nan, nan, nan],
#        [2008, 1, 24, ..., nan, nan, nan],
#        [2008, 1, 27, ..., 3.0, 0.0, 93.0],
#        ...,
#        [2008, 1, 5, ..., 24.0, 0.0, 0.0],
#        [2008, 1, 29, ..., nan, nan, nan],
#        [2008, 1, 20, ..., nan, nan, nan]], dtype=object)

# %% [markdown]
# como guardar la base de datos en otra estructura

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 66896  2008      1          23          3   1147.0        1150   1702.0
# 68652  2008      1          24          4   1224.0        1215   1533.0
# 79787  2008      1          27          7   1808.0        1635   1931.0
# 72143  2008      1          25          5   2107.0        2030   2330.0
# 57048  2008      1          20          7   1502.0        1500   1633.0
# 90970  2008      1          31          4   1246.0        1235   1510.0
# 89269  2008      1          30          3   1914.0        1915   2031.0
# 35553  2008      1          14          1    745.0         745    854.0
# 73891  2008      1          25          5   1020.0        1020   1207.0
# 14008  2008      1           7          1   1901.0        1850   2021.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 66896        1725            WN       1545  ...    4.0     17.0          0
# ...
